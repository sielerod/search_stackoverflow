# %%
import streamlit as st

tags = st.text_input('Informe a tag que deseja buscar. Ex: python, pandas')
tags = clean_text(tags).split(',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f588fa66c51a> in <module>
#       2
#       3 tags = st.text_input('Informe a tag que deseja buscar. Ex: python, pandas')
# ----> 4 tags = clean_text(tags).split(',')
#
# NameError: name 'clean_text' is not defined

# %%
#%run Read_Stackoverflow.ipynb

#result
# Out:
# Foram encontrados  98  perguntas no stackoverflow compatíveis com a sua busca. Veja as respostas mais relevantes:
# <style  type="text/css" >
# </style><table id="T_44f1c54a_cd3a_11ea_bbee_fc7774e0beb4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >title</th>        <th class="col_heading level0 col1" >link</th>        <th class="col_heading level0 col2" >summary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_44f1c54a_cd3a_11ea_bbee_fc7774e0beb4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_44f1c54a_cd3a_11ea_bbee_fc7774e0beb4row0_col0" class="data row0 col0" >'pip' is not recognized as an internal or external command</td>
# ...
